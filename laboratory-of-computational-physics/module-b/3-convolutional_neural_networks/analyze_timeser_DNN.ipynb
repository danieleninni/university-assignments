# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  10000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
#remove average value of each sample from its values
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x/400
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 8000   N_val= 2000   L= 60   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.2) ## raised to 0.2
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1
NF = 5

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# ----- Model 1 -----
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 50, 5)             60
#
#  average_pooling1d (AverageP  (None, 10, 5)            0
#  ooling1D)
#
#  conv1d_1 (Conv1D)           (None, 4, 5)              180
#
#  flatten (Flatten)           (None, 20)                0
#
#  dense (Dense)               (None, 12)                252
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_1 (Dense)             (None, 3)                 39
#
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-03-21 13:08:18.717477: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-21 13:08:18.718222: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Conv1D at 0x7f6bcd413a90>,
#  <keras.layers.pooling.AveragePooling1D at 0x7f6bcc517bb0>,
#  <keras.layers.convolutional.Conv1D at 0x7f6bcc424ca0>,
#  <keras.layers.core.flatten.Flatten at 0x7f6bcc517d30>,
#  <keras.layers.core.dense.Dense at 0x7f6bcc426590>,
#  <keras.layers.core.dropout.Dropout at 0x7f6bcc517c10>,
#  <keras.layers.core.dense.Dense at 0x7f6bcc425cc0>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 250
EPOCHS = 100

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/100
# 32/32 - 1s - loss: 1.1166 - accuracy: 0.3440 - val_loss: 1.1055 - val_accuracy: 0.3670 - 1s/epoch - 43ms/step
# Epoch 2/100
# 32/32 - 1s - loss: 1.0984 - accuracy: 0.3943 - val_loss: 1.0893 - val_accuracy: 0.3910 - 1s/epoch - 36ms/step
# Epoch 3/100
# 32/32 - 1s - loss: 1.0744 - accuracy: 0.4755 - val_loss: 1.0572 - val_accuracy: 0.5305 - 1s/epoch - 32ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 1.0298 - accuracy: 0.5691 - val_loss: 0.9961 - val_accuracy: 0.6545 - 392ms/epoch - 12ms/step
# Epoch 5/100
# 32/32 - 1s - loss: 0.9681 - accuracy: 0.6121 - val_loss: 0.9174 - val_accuracy: 0.6825 - 1s/epoch - 40ms/step
# Epoch 6/100
# 32/32 - 1s - loss: 0.8852 - accuracy: 0.6556 - val_loss: 0.8287 - val_accuracy: 0.7190 - 1s/epoch - 36ms/step
# Epoch 7/100
# 32/32 - 1s - loss: 0.8130 - accuracy: 0.6775 - val_loss: 0.7522 - val_accuracy: 0.7420 - 1s/epoch - 39ms/step
# Epoch 8/100
# 32/32 - 1s - loss: 0.7538 - accuracy: 0.7045 - val_loss: 0.6927 - val_accuracy: 0.7565 - 1s/epoch - 37ms/step
# Epoch 9/100
# 32/32 - 1s - loss: 0.7011 - accuracy: 0.7340 - val_loss: 0.6462 - val_accuracy: 0.7925 - 1s/epoch - 38ms/step
# Epoch 10/100
# 32/32 - 1s - loss: 0.6660 - accuracy: 0.7554 - val_loss: 0.6011 - val_accuracy: 0.8075 - 1s/epoch - 40ms/step
# Epoch 11/100
# 32/32 - 1s - loss: 0.6236 - accuracy: 0.7795 - val_loss: 0.5623 - val_accuracy: 0.8245 - 1s/epoch - 42ms/step
# Epoch 12/100
# 32/32 - 1s - loss: 0.5917 - accuracy: 0.7947 - val_loss: 0.5313 - val_accuracy: 0.8410 - 1s/epoch - 41ms/step
# Epoch 13/100
# 32/32 - 1s - loss: 0.5559 - accuracy: 0.8192 - val_loss: 0.4945 - val_accuracy: 0.8535 - 1s/epoch - 39ms/step
# Epoch 14/100
# 32/32 - 1s - loss: 0.5238 - accuracy: 0.8300 - val_loss: 0.4622 - val_accuracy: 0.8665 - 1s/epoch - 44ms/step
# Epoch 15/100
# 32/32 - 1s - loss: 0.4971 - accuracy: 0.8486 - val_loss: 0.4365 - val_accuracy: 0.8865 - 1s/epoch - 44ms/step
# Epoch 16/100
# 32/32 - 1s - loss: 0.4751 - accuracy: 0.8539 - val_loss: 0.4115 - val_accuracy: 0.8855 - 1s/epoch - 32ms/step
# Epoch 17/100
# 32/32 - 1s - loss: 0.4514 - accuracy: 0.8726 - val_loss: 0.3954 - val_accuracy: 0.8980 - 874ms/epoch - 27ms/step
# Epoch 18/100
# 32/32 - 1s - loss: 0.4333 - accuracy: 0.8724 - val_loss: 0.3751 - val_accuracy: 0.8965 - 1s/epoch - 38ms/step
# Epoch 19/100
# 32/32 - 1s - loss: 0.4134 - accuracy: 0.8769 - val_loss: 0.3534 - val_accuracy: 0.9075 - 1s/epoch - 43ms/step
# Epoch 20/100
# 32/32 - 1s - loss: 0.3971 - accuracy: 0.8903 - val_loss: 0.3372 - val_accuracy: 0.9085 - 1s/epoch - 36ms/step
# Epoch 21/100
# 32/32 - 1s - loss: 0.3808 - accuracy: 0.8972 - val_loss: 0.3238 - val_accuracy: 0.9155 - 1s/epoch - 37ms/step
# Epoch 22/100
# 32/32 - 1s - loss: 0.3631 - accuracy: 0.8999 - val_loss: 0.3134 - val_accuracy: 0.9185 - 1s/epoch - 37ms/step
# Epoch 23/100
# 32/32 - 1s - loss: 0.3560 - accuracy: 0.9039 - val_loss: 0.3018 - val_accuracy: 0.9190 - 1s/epoch - 38ms/step
# Epoch 24/100
# 32/32 - 1s - loss: 0.3461 - accuracy: 0.9025 - val_loss: 0.2944 - val_accuracy: 0.9230 - 838ms/epoch - 26ms/step
# Epoch 25/100
# 32/32 - 1s - loss: 0.3375 - accuracy: 0.9068 - val_loss: 0.2825 - val_accuracy: 0.9280 - 841ms/epoch - 26ms/step
# Epoch 26/100
# 32/32 - 1s - loss: 0.3246 - accuracy: 0.9143 - val_loss: 0.2748 - val_accuracy: 0.9325 - 1s/epoch - 36ms/step
# Epoch 27/100
# 32/32 - 1s - loss: 0.3183 - accuracy: 0.9135 - val_loss: 0.2677 - val_accuracy: 0.9315 - 1s/epoch - 39ms/step
# Epoch 28/100
# 32/32 - 1s - loss: 0.3123 - accuracy: 0.9153 - val_loss: 0.2648 - val_accuracy: 0.9340 - 1s/epoch - 45ms/step
# Epoch 29/100
# 32/32 - 1s - loss: 0.3054 - accuracy: 0.9174 - val_loss: 0.2553 - val_accuracy: 0.9350 - 1s/epoch - 42ms/step
# Epoch 30/100
# 32/32 - 1s - loss: 0.2949 - accuracy: 0.9181 - val_loss: 0.2522 - val_accuracy: 0.9345 - 1s/epoch - 39ms/step
# Epoch 31/100
# 32/32 - 1s - loss: 0.2860 - accuracy: 0.9251 - val_loss: 0.2436 - val_accuracy: 0.9410 - 1s/epoch - 43ms/step
# Epoch 32/100
# 32/32 - 1s - loss: 0.2830 - accuracy: 0.9241 - val_loss: 0.2422 - val_accuracy: 0.9405 - 588ms/epoch - 18ms/step
# Epoch 33/100
# 32/32 - 1s - loss: 0.2758 - accuracy: 0.9258 - val_loss: 0.2353 - val_accuracy: 0.9415 - 1s/epoch - 44ms/step
# Epoch 34/100
# 32/32 - 1s - loss: 0.2755 - accuracy: 0.9270 - val_loss: 0.2330 - val_accuracy: 0.9440 - 1s/epoch - 45ms/step
# Epoch 35/100
# 32/32 - 1s - loss: 0.2701 - accuracy: 0.9266 - val_loss: 0.2279 - val_accuracy: 0.9450 - 1s/epoch - 44ms/step
# Epoch 36/100
# 32/32 - 1s - loss: 0.2627 - accuracy: 0.9319 - val_loss: 0.2231 - val_accuracy: 0.9470 - 1s/epoch - 45ms/step
# Epoch 37/100
# 32/32 - 1s - loss: 0.2573 - accuracy: 0.9334 - val_loss: 0.2224 - val_accuracy: 0.9450 - 1s/epoch - 39ms/step
# Epoch 38/100
# 32/32 - 1s - loss: 0.2580 - accuracy: 0.9327 - val_loss: 0.2173 - val_accuracy: 0.9430 - 1s/epoch - 42ms/step
# Epoch 39/100
# 32/32 - 1s - loss: 0.2432 - accuracy: 0.9389 - val_loss: 0.2118 - val_accuracy: 0.9500 - 1s/epoch - 35ms/step
# Epoch 40/100
# 32/32 - 1s - loss: 0.2472 - accuracy: 0.9376 - val_loss: 0.2094 - val_accuracy: 0.9495 - 1s/epoch - 38ms/step
# Epoch 41/100
# 32/32 - 1s - loss: 0.2456 - accuracy: 0.9369 - val_loss: 0.2089 - val_accuracy: 0.9495 - 1s/epoch - 44ms/step
# Epoch 42/100
# 32/32 - 1s - loss: 0.2389 - accuracy: 0.9416 - val_loss: 0.2039 - val_accuracy: 0.9465 - 1s/epoch - 44ms/step
# Epoch 43/100
# 32/32 - 1s - loss: 0.2331 - accuracy: 0.9419 - val_loss: 0.2100 - val_accuracy: 0.9480 - 1s/epoch - 39ms/step
# Epoch 44/100
# 32/32 - 1s - loss: 0.2350 - accuracy: 0.9385 - val_loss: 0.2007 - val_accuracy: 0.9460 - 1s/epoch - 44ms/step
# Epoch 45/100
# 32/32 - 1s - loss: 0.2305 - accuracy: 0.9404 - val_loss: 0.1954 - val_accuracy: 0.9515 - 1s/epoch - 32ms/step
# Epoch 46/100
# 32/32 - 1s - loss: 0.2316 - accuracy: 0.9409 - val_loss: 0.1939 - val_accuracy: 0.9495 - 1s/epoch - 35ms/step
# Epoch 47/100
# 32/32 - 1s - loss: 0.2260 - accuracy: 0.9435 - val_loss: 0.1927 - val_accuracy: 0.9495 - 807ms/epoch - 25ms/step
# Epoch 48/100
# 32/32 - 1s - loss: 0.2227 - accuracy: 0.9426 - val_loss: 0.1919 - val_accuracy: 0.9480 - 1s/epoch - 39ms/step
# Epoch 49/100
# 32/32 - 1s - loss: 0.2187 - accuracy: 0.9426 - val_loss: 0.1954 - val_accuracy: 0.9495 - 1s/epoch - 32ms/step
# Epoch 50/100
# 32/32 - 1s - loss: 0.2164 - accuracy: 0.9467 - val_loss: 0.1854 - val_accuracy: 0.9490 - 1s/epoch - 40ms/step
# Epoch 51/100
# 32/32 - 1s - loss: 0.2187 - accuracy: 0.9425 - val_loss: 0.1824 - val_accuracy: 0.9515 - 1s/epoch - 40ms/step
# Epoch 52/100
# 32/32 - 2s - loss: 0.2116 - accuracy: 0.9461 - val_loss: 0.1830 - val_accuracy: 0.9525 - 2s/epoch - 47ms/step
# Epoch 53/100
# 32/32 - 1s - loss: 0.2078 - accuracy: 0.9480 - val_loss: 0.1814 - val_accuracy: 0.9500 - 610ms/epoch - 19ms/step
# Epoch 54/100
# 32/32 - 1s - loss: 0.2050 - accuracy: 0.9490 - val_loss: 0.1815 - val_accuracy: 0.9535 - 1s/epoch - 33ms/step
# Epoch 55/100
# 32/32 - 1s - loss: 0.2047 - accuracy: 0.9451 - val_loss: 0.1770 - val_accuracy: 0.9500 - 1s/epoch - 43ms/step
# Epoch 56/100
# 32/32 - 1s - loss: 0.2033 - accuracy: 0.9513 - val_loss: 0.1763 - val_accuracy: 0.9530 - 1s/epoch - 43ms/step
# Epoch 57/100
# 32/32 - 1s - loss: 0.2003 - accuracy: 0.9496 - val_loss: 0.1774 - val_accuracy: 0.9495 - 1s/epoch - 40ms/step
# Epoch 58/100
# 32/32 - 1s - loss: 0.1949 - accuracy: 0.9505 - val_loss: 0.1717 - val_accuracy: 0.9570 - 1s/epoch - 41ms/step
# Epoch 59/100
# 32/32 - 1s - loss: 0.1931 - accuracy: 0.9514 - val_loss: 0.1700 - val_accuracy: 0.9495 - 1s/epoch - 43ms/step
# Epoch 60/100
# 32/32 - 1s - loss: 0.1953 - accuracy: 0.9501 - val_loss: 0.1694 - val_accuracy: 0.9565 - 1s/epoch - 45ms/step
# Epoch 61/100
# 32/32 - 1s - loss: 0.1923 - accuracy: 0.9524 - val_loss: 0.1669 - val_accuracy: 0.9535 - 1s/epoch - 40ms/step
# Epoch 62/100
# 32/32 - 1s - loss: 0.1907 - accuracy: 0.9501 - val_loss: 0.1671 - val_accuracy: 0.9570 - 1s/epoch - 44ms/step
# Epoch 63/100
# 32/32 - 1s - loss: 0.1886 - accuracy: 0.9557 - val_loss: 0.1716 - val_accuracy: 0.9540 - 1s/epoch - 39ms/step
# Epoch 64/100
# 32/32 - 2s - loss: 0.1896 - accuracy: 0.9509 - val_loss: 0.1635 - val_accuracy: 0.9570 - 2s/epoch - 49ms/step
# Epoch 65/100
# 32/32 - 1s - loss: 0.1885 - accuracy: 0.9517 - val_loss: 0.1685 - val_accuracy: 0.9555 - 1s/epoch - 39ms/step
# Epoch 66/100
# 32/32 - 1s - loss: 0.1835 - accuracy: 0.9546 - val_loss: 0.1651 - val_accuracy: 0.9515 - 1s/epoch - 41ms/step
# Epoch 67/100
# 32/32 - 1s - loss: 0.1835 - accuracy: 0.9545 - val_loss: 0.1592 - val_accuracy: 0.9590 - 1s/epoch - 47ms/step
# Epoch 68/100
# 32/32 - 1s - loss: 0.1815 - accuracy: 0.9515 - val_loss: 0.1575 - val_accuracy: 0.9550 - 1s/epoch - 40ms/step
# Epoch 69/100
# 32/32 - 1s - loss: 0.1800 - accuracy: 0.9516 - val_loss: 0.1582 - val_accuracy: 0.9560 - 1s/epoch - 41ms/step
# Epoch 70/100
# 32/32 - 1s - loss: 0.1800 - accuracy: 0.9532 - val_loss: 0.1580 - val_accuracy: 0.9555 - 1s/epoch - 43ms/step
# Epoch 71/100
# 32/32 - 1s - loss: 0.1807 - accuracy: 0.9530 - val_loss: 0.1560 - val_accuracy: 0.9590 - 1s/epoch - 43ms/step
# Epoch 72/100
# 32/32 - 1s - loss: 0.1795 - accuracy: 0.9540 - val_loss: 0.1604 - val_accuracy: 0.9545 - 1s/epoch - 46ms/step
# Epoch 73/100
# 32/32 - 1s - loss: 0.1773 - accuracy: 0.9563 - val_loss: 0.1553 - val_accuracy: 0.9545 - 1s/epoch - 44ms/step
# Epoch 74/100
# 32/32 - 1s - loss: 0.1719 - accuracy: 0.9551 - val_loss: 0.1534 - val_accuracy: 0.9565 - 1s/epoch - 44ms/step
# Epoch 75/100
# 32/32 - 1s - loss: 0.1727 - accuracy: 0.9534 - val_loss: 0.1554 - val_accuracy: 0.9545 - 1s/epoch - 44ms/step
# Epoch 76/100
# 32/32 - 1s - loss: 0.1661 - accuracy: 0.9553 - val_loss: 0.1493 - val_accuracy: 0.9580 - 1s/epoch - 43ms/step
# Epoch 77/100
# 32/32 - 1s - loss: 0.1740 - accuracy: 0.9553 - val_loss: 0.1495 - val_accuracy: 0.9600 - 1s/epoch - 39ms/step
# Epoch 78/100
# 32/32 - 1s - loss: 0.1655 - accuracy: 0.9599 - val_loss: 0.1462 - val_accuracy: 0.9620 - 1s/epoch - 35ms/step
# Epoch 79/100
# 32/32 - 1s - loss: 0.1650 - accuracy: 0.9574 - val_loss: 0.1501 - val_accuracy: 0.9565 - 1s/epoch - 34ms/step
# Epoch 80/100
# 32/32 - 1s - loss: 0.1671 - accuracy: 0.9588 - val_loss: 0.1485 - val_accuracy: 0.9580 - 1s/epoch - 41ms/step
# Epoch 81/100
# 32/32 - 1s - loss: 0.1663 - accuracy: 0.9571 - val_loss: 0.1495 - val_accuracy: 0.9560 - 1s/epoch - 35ms/step
# Epoch 82/100
# 32/32 - 1s - loss: 0.1670 - accuracy: 0.9556 - val_loss: 0.1494 - val_accuracy: 0.9635 - 1s/epoch - 35ms/step
# Epoch 83/100
# 32/32 - 1s - loss: 0.1641 - accuracy: 0.9574 - val_loss: 0.1458 - val_accuracy: 0.9615 - 1s/epoch - 36ms/step
# Epoch 84/100
# 32/32 - 1s - loss: 0.1594 - accuracy: 0.9575 - val_loss: 0.1454 - val_accuracy: 0.9605 - 1s/epoch - 45ms/step
# Epoch 85/100
# 32/32 - 1s - loss: 0.1593 - accuracy: 0.9590 - val_loss: 0.1491 - val_accuracy: 0.9595 - 1s/epoch - 41ms/step
# Epoch 86/100
# 32/32 - 1s - loss: 0.1643 - accuracy: 0.9559 - val_loss: 0.1423 - val_accuracy: 0.9640 - 1s/epoch - 43ms/step
# Epoch 87/100
# 32/32 - 1s - loss: 0.1600 - accuracy: 0.9574 - val_loss: 0.1419 - val_accuracy: 0.9640 - 1s/epoch - 43ms/step
# Epoch 88/100
# 32/32 - 1s - loss: 0.1606 - accuracy: 0.9570 - val_loss: 0.1493 - val_accuracy: 0.9585 - 1s/epoch - 47ms/step
# Epoch 89/100
# 32/32 - 1s - loss: 0.1595 - accuracy: 0.9603 - val_loss: 0.1377 - val_accuracy: 0.9640 - 1s/epoch - 45ms/step
# Epoch 90/100
# 32/32 - 1s - loss: 0.1576 - accuracy: 0.9607 - val_loss: 0.1383 - val_accuracy: 0.9625 - 1s/epoch - 39ms/step
# Epoch 91/100
# 32/32 - 1s - loss: 0.1527 - accuracy: 0.9609 - val_loss: 0.1376 - val_accuracy: 0.9630 - 1s/epoch - 41ms/step
# Epoch 92/100
# 32/32 - 1s - loss: 0.1621 - accuracy: 0.9589 - val_loss: 0.1445 - val_accuracy: 0.9605 - 908ms/epoch - 28ms/step
# Epoch 93/100
# 32/32 - 1s - loss: 0.1548 - accuracy: 0.9603 - val_loss: 0.1399 - val_accuracy: 0.9620 - 1s/epoch - 40ms/step
# Epoch 94/100
# 32/32 - 1s - loss: 0.1535 - accuracy: 0.9592 - val_loss: 0.1360 - val_accuracy: 0.9620 - 1s/epoch - 42ms/step
# Epoch 95/100
# 32/32 - 1s - loss: 0.1517 - accuracy: 0.9615 - val_loss: 0.1377 - val_accuracy: 0.9655 - 1s/epoch - 41ms/step
# Epoch 96/100
# 32/32 - 1s - loss: 0.1502 - accuracy: 0.9620 - val_loss: 0.1382 - val_accuracy: 0.9620 - 1s/epoch - 44ms/step
# Epoch 97/100
# 32/32 - 1s - loss: 0.1532 - accuracy: 0.9606 - val_loss: 0.1315 - val_accuracy: 0.9650 - 1s/epoch - 40ms/step
# Epoch 98/100
# 32/32 - 1s - loss: 0.1460 - accuracy: 0.9641 - val_loss: 0.1320 - val_accuracy: 0.9645 - 1s/epoch - 39ms/step
# Epoch 99/100
# 32/32 - 1s - loss: 0.1495 - accuracy: 0.9620 - val_loss: 0.1323 - val_accuracy: 0.9655 - 1s/epoch - 39ms/step
# Epoch 100/100
# 32/32 - 1s - loss: 0.1445 - accuracy: 0.9631 - val_loss: 0.1362 - val_accuracy: 0.9635 - 1s/epoch - 36ms/step

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])

BATCH_SIZE2 = 250
EPOCHS2 = 100

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 32/32 - 2s - loss: 1.0674 - accuracy: 0.4364 - val_loss: 0.9576 - val_accuracy: 0.6285 - 2s/epoch - 55ms/step
# Epoch 2/100
# 32/32 - 1s - loss: 0.8390 - accuracy: 0.6908 - val_loss: 0.7006 - val_accuracy: 0.7915 - 566ms/epoch - 18ms/step
# Epoch 3/100
# 32/32 - 1s - loss: 0.6360 - accuracy: 0.7889 - val_loss: 0.5213 - val_accuracy: 0.8545 - 1s/epoch - 36ms/step
# Epoch 4/100
# 32/32 - 1s - loss: 0.5070 - accuracy: 0.8504 - val_loss: 0.4291 - val_accuracy: 0.8875 - 1s/epoch - 34ms/step
# Epoch 5/100
# 32/32 - 1s - loss: 0.4229 - accuracy: 0.8832 - val_loss: 0.3530 - val_accuracy: 0.9080 - 1s/epoch - 40ms/step
# Epoch 6/100
# 32/32 - 1s - loss: 0.3713 - accuracy: 0.9051 - val_loss: 0.3057 - val_accuracy: 0.9250 - 1s/epoch - 40ms/step
# Epoch 7/100
# 32/32 - 1s - loss: 0.3261 - accuracy: 0.9169 - val_loss: 0.2787 - val_accuracy: 0.9340 - 1s/epoch - 37ms/step
# Epoch 8/100
# 32/32 - 1s - loss: 0.3029 - accuracy: 0.9265 - val_loss: 0.2551 - val_accuracy: 0.9385 - 1s/epoch - 41ms/step
# Epoch 9/100
# 32/32 - 2s - loss: 0.2839 - accuracy: 0.9309 - val_loss: 0.2487 - val_accuracy: 0.9365 - 2s/epoch - 48ms/step
# Epoch 10/100
# 32/32 - 2s - loss: 0.2687 - accuracy: 0.9352 - val_loss: 0.2310 - val_accuracy: 0.9410 - 2s/epoch - 49ms/step
# Epoch 11/100
# 32/32 - 1s - loss: 0.2567 - accuracy: 0.9406 - val_loss: 0.2219 - val_accuracy: 0.9490 - 1s/epoch - 37ms/step
# Epoch 12/100
# 32/32 - 1s - loss: 0.2384 - accuracy: 0.9456 - val_loss: 0.2048 - val_accuracy: 0.9560 - 1s/epoch - 41ms/step
# Epoch 13/100
# 32/32 - 1s - loss: 0.2332 - accuracy: 0.9441 - val_loss: 0.1958 - val_accuracy: 0.9585 - 1s/epoch - 41ms/step
# Epoch 14/100
# 32/32 - 1s - loss: 0.2242 - accuracy: 0.9494 - val_loss: 0.1950 - val_accuracy: 0.9570 - 1s/epoch - 37ms/step
# Epoch 15/100
# 32/32 - 1s - loss: 0.2174 - accuracy: 0.9504 - val_loss: 0.1901 - val_accuracy: 0.9605 - 1s/epoch - 37ms/step
# Epoch 16/100
# 32/32 - 1s - loss: 0.2057 - accuracy: 0.9540 - val_loss: 0.1744 - val_accuracy: 0.9645 - 1s/epoch - 38ms/step
# Epoch 17/100
# 32/32 - 1s - loss: 0.2032 - accuracy: 0.9549 - val_loss: 0.1788 - val_accuracy: 0.9610 - 1s/epoch - 39ms/step
# Epoch 18/100
# 32/32 - 1s - loss: 0.1944 - accuracy: 0.9570 - val_loss: 0.1647 - val_accuracy: 0.9665 - 1s/epoch - 43ms/step
# Epoch 19/100
# 32/32 - 1s - loss: 0.1824 - accuracy: 0.9614 - val_loss: 0.1583 - val_accuracy: 0.9695 - 1s/epoch - 40ms/step
# Epoch 20/100
# 32/32 - 1s - loss: 0.1850 - accuracy: 0.9600 - val_loss: 0.1537 - val_accuracy: 0.9680 - 1s/epoch - 39ms/step
# Epoch 21/100
# 32/32 - 1s - loss: 0.1761 - accuracy: 0.9619 - val_loss: 0.1491 - val_accuracy: 0.9720 - 1s/epoch - 35ms/step
# Epoch 22/100
# 32/32 - 1s - loss: 0.1725 - accuracy: 0.9644 - val_loss: 0.1456 - val_accuracy: 0.9715 - 1s/epoch - 37ms/step
# Epoch 23/100
# 32/32 - 1s - loss: 0.1656 - accuracy: 0.9647 - val_loss: 0.1412 - val_accuracy: 0.9730 - 1s/epoch - 43ms/step
# Epoch 24/100
# 32/32 - 1s - loss: 0.1630 - accuracy: 0.9651 - val_loss: 0.1354 - val_accuracy: 0.9725 - 1s/epoch - 36ms/step
# Epoch 25/100
# 32/32 - 2s - loss: 0.1587 - accuracy: 0.9676 - val_loss: 0.1341 - val_accuracy: 0.9735 - 2s/epoch - 48ms/step
# Epoch 26/100
# 32/32 - 2s - loss: 0.1579 - accuracy: 0.9655 - val_loss: 0.1344 - val_accuracy: 0.9740 - 2s/epoch - 48ms/step
# Epoch 27/100
# 32/32 - 1s - loss: 0.1533 - accuracy: 0.9665 - val_loss: 0.1283 - val_accuracy: 0.9740 - 1s/epoch - 43ms/step
# Epoch 28/100
# 32/32 - 1s - loss: 0.1510 - accuracy: 0.9685 - val_loss: 0.1287 - val_accuracy: 0.9735 - 1s/epoch - 41ms/step
# Epoch 29/100
# 32/32 - 1s - loss: 0.1434 - accuracy: 0.9709 - val_loss: 0.1262 - val_accuracy: 0.9770 - 1s/epoch - 46ms/step
# Epoch 30/100
# 32/32 - 1s - loss: 0.1413 - accuracy: 0.9697 - val_loss: 0.1245 - val_accuracy: 0.9755 - 1s/epoch - 42ms/step
# Epoch 31/100
# 32/32 - 2s - loss: 0.1413 - accuracy: 0.9686 - val_loss: 0.1239 - val_accuracy: 0.9745 - 2s/epoch - 48ms/step
# Epoch 32/100
# 32/32 - 1s - loss: 0.1389 - accuracy: 0.9720 - val_loss: 0.1233 - val_accuracy: 0.9755 - 1s/epoch - 47ms/step
# Epoch 33/100
# 32/32 - 1s - loss: 0.1386 - accuracy: 0.9703 - val_loss: 0.1155 - val_accuracy: 0.9765 - 1s/epoch - 38ms/step
# Epoch 34/100
# 32/32 - 1s - loss: 0.1332 - accuracy: 0.9710 - val_loss: 0.1216 - val_accuracy: 0.9765 - 1s/epoch - 41ms/step
# Epoch 35/100
# 32/32 - 1s - loss: 0.1335 - accuracy: 0.9718 - val_loss: 0.1150 - val_accuracy: 0.9780 - 1s/epoch - 37ms/step
# Epoch 36/100
# 32/32 - 1s - loss: 0.1307 - accuracy: 0.9724 - val_loss: 0.1135 - val_accuracy: 0.9790 - 1s/epoch - 33ms/step
# Epoch 37/100
# 32/32 - 2s - loss: 0.1267 - accuracy: 0.9744 - val_loss: 0.1116 - val_accuracy: 0.9785 - 2s/epoch - 50ms/step
# Epoch 38/100
# 32/32 - 1s - loss: 0.1273 - accuracy: 0.9726 - val_loss: 0.1070 - val_accuracy: 0.9790 - 988ms/epoch - 31ms/step
# Epoch 39/100
# 32/32 - 1s - loss: 0.1283 - accuracy: 0.9735 - val_loss: 0.1092 - val_accuracy: 0.9795 - 1s/epoch - 46ms/step
# Epoch 40/100
# 32/32 - 1s - loss: 0.1262 - accuracy: 0.9737 - val_loss: 0.1069 - val_accuracy: 0.9775 - 1s/epoch - 43ms/step
# Epoch 41/100
# 32/32 - 1s - loss: 0.1232 - accuracy: 0.9756 - val_loss: 0.1079 - val_accuracy: 0.9800 - 1s/epoch - 43ms/step
# Epoch 42/100
# 32/32 - 1s - loss: 0.1219 - accuracy: 0.9743 - val_loss: 0.1045 - val_accuracy: 0.9800 - 1s/epoch - 45ms/step
# Epoch 43/100
# 32/32 - 1s - loss: 0.1169 - accuracy: 0.9758 - val_loss: 0.1036 - val_accuracy: 0.9770 - 1s/epoch - 41ms/step
# Epoch 44/100
# 32/32 - 1s - loss: 0.1165 - accuracy: 0.9762 - val_loss: 0.1051 - val_accuracy: 0.9780 - 1s/epoch - 38ms/step
# Epoch 45/100
# 32/32 - 1s - loss: 0.1215 - accuracy: 0.9737 - val_loss: 0.1006 - val_accuracy: 0.9810 - 1s/epoch - 35ms/step
# Epoch 46/100
# 32/32 - 1s - loss: 0.1180 - accuracy: 0.9758 - val_loss: 0.1005 - val_accuracy: 0.9785 - 1s/epoch - 34ms/step
# Epoch 47/100
# 32/32 - 1s - loss: 0.1135 - accuracy: 0.9765 - val_loss: 0.1016 - val_accuracy: 0.9790 - 925ms/epoch - 29ms/step
# Epoch 48/100
# 32/32 - 1s - loss: 0.1156 - accuracy: 0.9746 - val_loss: 0.0970 - val_accuracy: 0.9820 - 1s/epoch - 35ms/step
# Epoch 49/100
# 32/32 - 1s - loss: 0.1122 - accuracy: 0.9760 - val_loss: 0.0965 - val_accuracy: 0.9805 - 1s/epoch - 37ms/step
# Epoch 50/100
# 32/32 - 1s - loss: 0.1091 - accuracy: 0.9765 - val_loss: 0.1022 - val_accuracy: 0.9785 - 1s/epoch - 35ms/step
# Epoch 51/100
# 32/32 - 1s - loss: 0.1145 - accuracy: 0.9743 - val_loss: 0.0965 - val_accuracy: 0.9810 - 1s/epoch - 42ms/step
# Epoch 52/100
# 32/32 - 1s - loss: 0.1089 - accuracy: 0.9765 - val_loss: 0.0962 - val_accuracy: 0.9790 - 1s/epoch - 43ms/step
# Epoch 53/100
# 32/32 - 1s - loss: 0.1074 - accuracy: 0.9761 - val_loss: 0.0945 - val_accuracy: 0.9830 - 1s/epoch - 38ms/step
# Epoch 54/100
# 32/32 - 1s - loss: 0.1089 - accuracy: 0.9760 - val_loss: 0.0950 - val_accuracy: 0.9800 - 1s/epoch - 36ms/step
# Epoch 55/100
# 32/32 - 1s - loss: 0.1029 - accuracy: 0.9787 - val_loss: 0.0920 - val_accuracy: 0.9830 - 1s/epoch - 44ms/step
# Epoch 56/100
# 32/32 - 1s - loss: 0.1030 - accuracy: 0.9789 - val_loss: 0.0945 - val_accuracy: 0.9800 - 1s/epoch - 46ms/step
# Epoch 57/100
# 32/32 - 1s - loss: 0.1041 - accuracy: 0.9794 - val_loss: 0.0884 - val_accuracy: 0.9820 - 1s/epoch - 44ms/step
# Epoch 58/100
# 32/32 - 1s - loss: 0.1023 - accuracy: 0.9779 - val_loss: 0.0891 - val_accuracy: 0.9815 - 1s/epoch - 41ms/step
# Epoch 59/100
# 32/32 - 1s - loss: 0.0993 - accuracy: 0.9786 - val_loss: 0.0915 - val_accuracy: 0.9805 - 1s/epoch - 43ms/step
# Epoch 60/100
# 32/32 - 1s - loss: 0.1014 - accuracy: 0.9769 - val_loss: 0.0893 - val_accuracy: 0.9810 - 1s/epoch - 47ms/step
# Epoch 61/100
# 32/32 - 1s - loss: 0.1018 - accuracy: 0.9795 - val_loss: 0.0866 - val_accuracy: 0.9830 - 1s/epoch - 44ms/step
# Epoch 62/100
# 32/32 - 1s - loss: 0.1001 - accuracy: 0.9790 - val_loss: 0.0864 - val_accuracy: 0.9835 - 1s/epoch - 38ms/step
# Epoch 63/100
# 32/32 - 1s - loss: 0.0965 - accuracy: 0.9801 - val_loss: 0.0912 - val_accuracy: 0.9800 - 1s/epoch - 42ms/step
# Epoch 64/100
# 32/32 - 1s - loss: 0.0997 - accuracy: 0.9760 - val_loss: 0.0861 - val_accuracy: 0.9810 - 1s/epoch - 44ms/step
# Epoch 65/100
# 32/32 - 0s - loss: 0.0981 - accuracy: 0.9790 - val_loss: 0.0870 - val_accuracy: 0.9810 - 404ms/epoch - 13ms/step
# Epoch 66/100
# 32/32 - 1s - loss: 0.0970 - accuracy: 0.9786 - val_loss: 0.0933 - val_accuracy: 0.9775 - 525ms/epoch - 16ms/step
# Epoch 67/100
# 32/32 - 1s - loss: 0.0965 - accuracy: 0.9801 - val_loss: 0.0874 - val_accuracy: 0.9825 - 668ms/epoch - 21ms/step
# Epoch 68/100
# 32/32 - 1s - loss: 0.0943 - accuracy: 0.9809 - val_loss: 0.0857 - val_accuracy: 0.9840 - 1s/epoch - 43ms/step
# Epoch 69/100
# 32/32 - 1s - loss: 0.0958 - accuracy: 0.9799 - val_loss: 0.0836 - val_accuracy: 0.9825 - 1s/epoch - 43ms/step
# Epoch 70/100
# 32/32 - 1s - loss: 0.0908 - accuracy: 0.9799 - val_loss: 0.0840 - val_accuracy: 0.9825 - 1s/epoch - 37ms/step
# Epoch 71/100
# 32/32 - 1s - loss: 0.0947 - accuracy: 0.9789 - val_loss: 0.0801 - val_accuracy: 0.9845 - 1s/epoch - 39ms/step
# Epoch 72/100
# 32/32 - 1s - loss: 0.0934 - accuracy: 0.9811 - val_loss: 0.0849 - val_accuracy: 0.9825 - 1s/epoch - 37ms/step
# Epoch 73/100
# 32/32 - 2s - loss: 0.0928 - accuracy: 0.9796 - val_loss: 0.0814 - val_accuracy: 0.9820 - 2s/epoch - 47ms/step
# Epoch 74/100
# 32/32 - 2s - loss: 0.0919 - accuracy: 0.9804 - val_loss: 0.0795 - val_accuracy: 0.9855 - 2s/epoch - 49ms/step
# Epoch 75/100
# 32/32 - 1s - loss: 0.0890 - accuracy: 0.9818 - val_loss: 0.0781 - val_accuracy: 0.9840 - 1s/epoch - 46ms/step
# Epoch 76/100
# 32/32 - 2s - loss: 0.0899 - accuracy: 0.9805 - val_loss: 0.0792 - val_accuracy: 0.9840 - 2s/epoch - 48ms/step
# Epoch 77/100
# 32/32 - 1s - loss: 0.0916 - accuracy: 0.9789 - val_loss: 0.0821 - val_accuracy: 0.9825 - 1s/epoch - 42ms/step
# Epoch 78/100
# 32/32 - 1s - loss: 0.0932 - accuracy: 0.9781 - val_loss: 0.0835 - val_accuracy: 0.9825 - 1s/epoch - 32ms/step
# Epoch 79/100
# 32/32 - 1s - loss: 0.0869 - accuracy: 0.9822 - val_loss: 0.0800 - val_accuracy: 0.9845 - 1s/epoch - 34ms/step
# Epoch 80/100
# 32/32 - 1s - loss: 0.0915 - accuracy: 0.9797 - val_loss: 0.0812 - val_accuracy: 0.9810 - 920ms/epoch - 29ms/step
# Epoch 81/100
# 32/32 - 1s - loss: 0.0883 - accuracy: 0.9809 - val_loss: 0.0776 - val_accuracy: 0.9825 - 1s/epoch - 41ms/step
# Epoch 82/100
# 32/32 - 1s - loss: 0.0875 - accuracy: 0.9787 - val_loss: 0.0796 - val_accuracy: 0.9830 - 1s/epoch - 44ms/step
# Epoch 83/100
# 32/32 - 1s - loss: 0.0850 - accuracy: 0.9820 - val_loss: 0.0764 - val_accuracy: 0.9845 - 1s/epoch - 42ms/step
# Epoch 84/100
# 32/32 - 1s - loss: 0.0867 - accuracy: 0.9815 - val_loss: 0.0786 - val_accuracy: 0.9830 - 1s/epoch - 38ms/step
# Epoch 85/100
# 32/32 - 1s - loss: 0.0853 - accuracy: 0.9806 - val_loss: 0.0754 - val_accuracy: 0.9840 - 1s/epoch - 45ms/step
# Epoch 86/100
# 32/32 - 2s - loss: 0.0843 - accuracy: 0.9811 - val_loss: 0.0783 - val_accuracy: 0.9835 - 2s/epoch - 47ms/step
# Epoch 87/100
# 32/32 - 1s - loss: 0.0848 - accuracy: 0.9810 - val_loss: 0.0794 - val_accuracy: 0.9840 - 1s/epoch - 38ms/step
# Epoch 88/100
# 32/32 - 1s - loss: 0.0840 - accuracy: 0.9809 - val_loss: 0.0803 - val_accuracy: 0.9830 - 926ms/epoch - 29ms/step
# Epoch 89/100
# 32/32 - 1s - loss: 0.0863 - accuracy: 0.9820 - val_loss: 0.0750 - val_accuracy: 0.9845 - 1s/epoch - 45ms/step
# Epoch 90/100
# 32/32 - 1s - loss: 0.0808 - accuracy: 0.9824 - val_loss: 0.0736 - val_accuracy: 0.9845 - 1s/epoch - 37ms/step
# Epoch 91/100
# 32/32 - 1s - loss: 0.0819 - accuracy: 0.9820 - val_loss: 0.0837 - val_accuracy: 0.9805 - 1s/epoch - 41ms/step
# Epoch 92/100
# 32/32 - 1s - loss: 0.0852 - accuracy: 0.9808 - val_loss: 0.0773 - val_accuracy: 0.9830 - 1s/epoch - 39ms/step
# Epoch 93/100
# 32/32 - 1s - loss: 0.0824 - accuracy: 0.9819 - val_loss: 0.0769 - val_accuracy: 0.9825 - 1s/epoch - 42ms/step
# Epoch 94/100
# 32/32 - 1s - loss: 0.0806 - accuracy: 0.9815 - val_loss: 0.0780 - val_accuracy: 0.9830 - 1s/epoch - 44ms/step
# Epoch 95/100
# 32/32 - 1s - loss: 0.0862 - accuracy: 0.9803 - val_loss: 0.0760 - val_accuracy: 0.9825 - 1s/epoch - 40ms/step
# Epoch 96/100
# 32/32 - 1s - loss: 0.0791 - accuracy: 0.9844 - val_loss: 0.0761 - val_accuracy: 0.9830 - 1s/epoch - 40ms/step
# Epoch 97/100
# 32/32 - 1s - loss: 0.0824 - accuracy: 0.9821 - val_loss: 0.0738 - val_accuracy: 0.9830 - 1s/epoch - 44ms/step
# Epoch 98/100
# 32/32 - 1s - loss: 0.0794 - accuracy: 0.9839 - val_loss: 0.0746 - val_accuracy: 0.9830 - 1s/epoch - 45ms/step
# Epoch 99/100
# 32/32 - 1s - loss: 0.0776 - accuracy: 0.9839 - val_loss: 0.0701 - val_accuracy: 0.9860 - 1s/epoch - 34ms/step
# Epoch 100/100
# 32/32 - 1s - loss: 0.0779 - accuracy: 0.9816 - val_loss: 0.0721 - val_accuracy: 0.9845 - 1s/epoch - 38ms/step

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"]
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))
